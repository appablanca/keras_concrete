# %%
import keras 
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# Importing the modules

# %%
data = pd.read_csv('concrete_data.csv')
data
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 0               1040.0           676.0   28     79.99
# 1               1055.0           676.0   28     61.89
# 2                932.0           594.0  270     40.27
# 3                932.0           594.0  365     41.05
# 4                978.4           825.5  360     44.30
# ...                ...             ...  ...       ...
# 1025             870.1           768.3   28     44.28
# 1026             817.9           813.4   28     31.18
# 1027             892.4           780.0   28     23.70
# 1028             989.6           788.9   28     32.77
# 1029             864.5           761.5   28     32.40
#
# [1030 rows x 9 columns]

# %% [markdown]
# Reading the csv file

# %%
model = Sequential()
n_cols = data.shape[1] - 1  # number of columns -1 because we disgard strength which is the targer

model.add(Dense(10, activation='relu', input_shape=(n_cols,))) #hidden layer
model.add(Dense(1))  #output layer
model.compile(optimizer='adam', loss='mean_squared_error') #optimizng data with adam and loss function mean squared error

X = data.drop('Strength', axis=1) #drop the target column
y = data['Strength'] #target column
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42) #split the data into training and testing data

model.fit(X_train, y_train, epochs=50) #fit the model with the training data
# Out:
# Epoch 1/50
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/core/dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 347us/step - loss: 691231.6875
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - loss: 369237.1562
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 160329.6875
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - loss: 59242.9219
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 264us/step - loss: 17825.4023
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 267us/step - loss: 8379.6084
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 253us/step - loss: 5582.0479
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 247us/step - loss: 4986.8931
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 256us/step - loss: 5020.0850
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 250us/step - loss: 4783.1450
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 256us/step - loss: 4488.0449
# Epoch 12/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 267us/step - loss: 3615.9751
# Epoch 13/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 249us/step - loss: 3410.5813
# Epoch 14/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 250us/step - loss: 3257.9419
# Epoch 15/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 266us/step - loss: 2799.2888
# Epoch 16/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 255us/step - loss: 2870.8152
# Epoch 17/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 276us/step - loss: 2772.7085
# Epoch 18/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 264us/step - loss: 2475.3474
# Epoch 19/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 274us/step - loss: 2167.1179
# Epoch 20/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 278us/step - loss: 1910.7538
# Epoch 21/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 268us/step - loss: 1885.6555
# Epoch 22/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 268us/step - loss: 1848.1627
# Epoch 23/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 262us/step - loss: 1555.8402
# Epoch 24/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 266us/step - loss: 1462.9264
# Epoch 25/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 263us/step - loss: 1476.0613
# Epoch 26/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 262us/step - loss: 1352.3959
# Epoch 27/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 270us/step - loss: 1187.3831
# Epoch 28/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 267us/step - loss: 1130.3813
# Epoch 29/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 288us/step - loss: 1017.7310
# Epoch 30/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 253us/step - loss: 935.9305
# Epoch 31/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 272us/step - loss: 841.9802
# Epoch 32/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 254us/step - loss: 776.7231
# Epoch 33/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 269us/step - loss: 781.4424
# Epoch 34/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 272us/step - loss: 715.8491
# Epoch 35/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 263us/step - loss: 673.4164
# Epoch 36/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 273us/step - loss: 621.9852
# Epoch 37/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 259us/step - loss: 625.8406
# Epoch 38/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 591.6523
# Epoch 39/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - loss: 572.2869
# Epoch 40/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 250us/step - loss: 551.9665
# Epoch 41/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 268us/step - loss: 585.2595
# Epoch 42/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 263us/step - loss: 526.8014
# Epoch 43/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 263us/step - loss: 479.4278
# Epoch 44/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 261us/step - loss: 424.3515
# Epoch 45/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 263us/step - loss: 457.0274
# Epoch 46/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 259us/step - loss: 440.8934
# Epoch 47/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 266us/step - loss: 383.5179
# Epoch 48/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 259us/step - loss: 426.3103
# Epoch 49/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 265us/step - loss: 387.9005
# Epoch 50/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 253us/step - loss: 412.6844

# %%
lossvalls = []
for i in range(50):
    model.fit(X_train, y_train, epochs=50, verbose=0)
    loss_val = model.evaluate(X_test, y_test)
    lossvalls.append(loss_val)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 279us/step - loss: 199.6614
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 282us/step - loss: 145.6787
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 277us/step - loss: 113.3138
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 270us/step - loss: 101.3382
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 275us/step - loss: 86.7409
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 280us/step - loss: 73.8798
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 278us/step - loss: 71.9129
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 271us/step - loss: 55.1050
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 277us/step - loss: 77.6837
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - loss: 52.8907
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 244us/step - loss: 50.6073
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 248us/step - loss: 52.7336
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 247us/step - loss: 73.1180
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 251us/step - loss: 52.6168
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 284us/step - loss: 47.9836
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 242us/step - loss: 47.9200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 263us/step - loss: 48.6406
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 247us/step - loss: 49.9654
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 245us/step - loss: 47.3549
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 262us/step - loss: 47.4143
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 264us/step - loss: 47.1617
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 253us/step - loss: 47.0579
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 243us/step - loss: 47.6215
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step - loss: 52.1197
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 281us/step - loss: 48.0401
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - loss: 47.5756
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 259us/step - loss: 62.6519
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 265us/step - loss: 48.8434
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 257us/step - loss: 47.5574
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 247us/step - loss: 50.7933
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 258us/step - loss: 51.8124
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 251us/step - loss: 51.5861
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 254us/step - loss: 48.3159
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 245us/step - loss: 47.1473
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 256us/step - loss: 54.8341
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 283us/step - loss: 50.4416
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 242us/step - loss: 46.3545
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 240us/step - loss: 47.3891
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 247us/step - loss: 48.1999
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 261us/step - loss: 56.1918
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 258us/step - loss: 48.1996
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 248us/step - loss: 52.4169
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 252us/step - loss: 50.6865
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 243us/step - loss: 46.5200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 246us/step - loss: 46.0952
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 244us/step - loss: 45.6525
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 263us/step - loss: 46.9259
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 246us/step - loss: 75.2276
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 256us/step - loss: 49.1173
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 235us/step - loss: 46.0857

# %%
mean = np.mean(lossvalls)
print("Mean of lossvalues",mean)
std = np.std(lossvalls)
print("Standard deviation of lossvalues",std)
# Out:
# Mean of lossvalues 63.54134391784668
# Standard deviation of lossvalues 29.28253611317058
